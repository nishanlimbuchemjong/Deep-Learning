#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ------------------------------------- -- 7.6/8.0 MB 129.0 kB/s eta 0:00:04
#    ---------------------------------------  7.9/8.0 MB 121.8 kB/s eta 0:00:02
#    ---------------------------------------  7.9/8.0 MB 121.8 kB/s eta 0:00:02
#    ---------------------------------------  7.9/8.0 MB 121.8 kB/s eta 0:00:02
#    ---------------------------------------- 8.0/8.0 MB 124.6 kB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.3-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 75.6 kB/s eta 0:00:23
#    --------- ------------------------------ 0.5/2.2 MB 75.6 kB/s eta 0:00:23
#    --------- ------------------------------ 0.5/2.2 MB 75.6 kB/s eta 0:00:23
#    --------- ------------------------------ 0.5/2.2 MB 75.6 kB/s eta 0:00:23
#    --------- ------------------------------ 0.5/2.2 MB 75.6 kB/s eta 0:00:23
#    --------- ------------------------------ 0.5/2.2 MB 75.6 kB/s eta 0:00:23
#    --------- ------------------------------ 0.5/2.2 MB 75.6 kB/s eta 0:00:23
#    -------------- ------------------------- 0.8/2.2 MB 108.9 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 108.9 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 108.9 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 108.9 kB/s eta 0:00:14
#    -------------- ------------------------- 0.8/2.2 MB 108.9 kB/s eta 0:00:14
#    ------------------ --------------------- 1.0/2.2 MB 129.7 kB/s eta 0:00:09
#    ------------------ --------------------- 1.0/2.2 MB 129.7 kB/s eta 0:00:09
#    ------------------ --------------------- 1.0/2.2 MB 129.7 kB/s eta 0:00:09
#    ------------------ --------------------- 1.0/2.2 MB 129.7 kB/s eta 0:00:09
#    ----------------------- ---------------- 1.3/2.2 MB 153.9 kB/s eta 0:00:06
#    ----------------------- ---------------- 1.3/2.2 MB 153.9 kB/s eta 0:00:06
#    ----------------------- ---------------- 1.3/2.2 MB 153.9 kB/s eta 0:00:06
#    ---------------------------- ----------- 1.6/2.2 MB 173.0 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.6/2.2 MB 173.0 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.6/2.2 MB 173.0 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.6/2.2 MB 173.0 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.6/2.2 MB 173.0 kB/s eta 0:00:04
#    --------------------------------- ------ 1.8/2.2 MB 185.0 kB/s eta 0:00:03
#    --------------------------------- ------ 1.8/2.2 MB 185.0 kB/s eta 0:00:03
#    ------------------------------------- -- 2.1/2.2 MB 203.9 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 209.4 kB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading pillow-11.1.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.6 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.6 MB 599.9 kB/s eta 0:00:04
#    ------- -------------------------------- 0.5/2.6 MB 599.9 kB/s eta 0:00:04
#    ----------- ---------------------------- 0.8/2.6 MB 559.5 kB/s eta 0:00:04
#    ----------- ---------------------------- 0.8/2.6 MB 559.5 kB/s eta 0:00:04
#    ----------- ---------------------------- 0.8/2.6 MB 559.5 kB/s eta 0:00:04
#    ----------- ---------------------------- 0.8/2.6 MB 559.5 kB/s eta 0:00:04
#    --------------- ------------------------ 1.0/2.6 MB 461.8 kB/s eta 0:00:04
#    --------------- ------------------------ 1.0/2.6 MB 461.8 kB/s eta 0:00:04
#    ------------------- -------------------- 1.3/2.6 MB 476.0 kB/s eta 0:00:03
#    ------------------- -------------------- 1.3/2.6 MB 476.0 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.6/2.6 MB 482.1 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.6/2.6 MB 482.1 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.6/2.6 MB 482.1 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.6/2.6 MB 482.1 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.6/2.6 MB 482.1 kB/s eta 0:00:03
#    ----------------------- ---------------- 1.6/2.6 MB 482.1 kB/s eta 0:00:03
#    --------------------------- ------------ 1.8/2.6 MB 399.5 kB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.6 MB 399.5 kB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.6 MB 399.5 kB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.6 MB 399.5 kB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.6 MB 399.5 kB/s eta 0:00:02
#    ------------------------------- -------- 2.1/2.6 MB 374.0 kB/s eta 0:00:02
#    ------------------------------- -------- 2.1/2.6 MB 374.0 kB/s eta 0:00:02
#    ------------------------------- -------- 2.1/2.6 MB 374.0 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.4/2.6 MB 374.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.6 MB 374.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.6 MB 374.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.6 MB 374.9 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.6 MB 374.9 kB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 350.3 kB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.3 kiwisolver-1.4.8 matplotlib-3.10.0 pillow-11.1.0 pyparsing-3.2.1

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('dataset/Churn_Modelling.csv')
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
cols = ['RowNumber', 'CustomerId', 'Surname', 'Geography', 'Gender']
dataset = dataset.drop(columns=cols, axis=1)
dataset.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1
# 3               0         93826.63       0
# 4               1         79084.10       0

# %%
# checking the presence of null
dataset.isnull().sum()
# Out:
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# diving dataset into independent or dependent features (input or output)
input_dataset = dataset.iloc[:, :-1]
output_dataset = dataset.iloc[:, -1]

# %%
# Now scaling the input_dataset
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
input_scaled = ss.fit_transform(input_dataset)

# %%
# converting the input-scaled dataset into dataframe
input_dataset = pd.DataFrame(input_scaled, columns=input_dataset.columns)
input_dataset
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0       -0.326221  0.293517 -1.041760 -1.225848      -0.911583   0.646092
# 1       -0.440036  0.198164 -1.387538  0.117350      -0.911583  -1.547768
# 2       -1.536794  0.293517  1.032908  1.333053       2.527057   0.646092
# 3        0.501521  0.007457 -1.387538 -1.225848       0.807737  -1.547768
# 4        2.063884  0.388871 -1.041760  0.785728      -0.911583   0.646092
# ...           ...       ...       ...       ...            ...        ...
# 9995     1.246488  0.007457 -0.004426 -1.225848       0.807737   0.646092
# 9996    -1.391939 -0.373958  1.724464 -0.306379      -0.911583   0.646092
# 9997     0.604988 -0.278604  0.687130 -1.225848      -0.911583  -1.547768
# 9998     1.256835  0.293517 -0.695982 -0.022608       0.807737   0.646092
# 9999     1.463771 -1.041433 -0.350204  0.859965      -0.911583   0.646092
#
#       IsActiveMember  EstimatedSalary
# 0           0.970243         0.021886
# 1           0.970243         0.216534
# 2          -1.030670         0.240687
# 3          -1.030670        -0.108918
# 4           0.970243        -0.365276
# ...              ...              ...
# 9995       -1.030670        -0.066419
# 9996        0.970243         0.027988
# 9997        0.970243        -1.008643
# 9998       -1.030670        -0.125231
# 9999       -1.030670        -1.076370
#
# [10000 rows x 8 columns]

# %%
X_test
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 6252          596   32       3   96709.07              2          0
# 4684          623   43       1       0.00              2          1
# 1731          601   44       4       0.00              2          1
# 4742          506   59       8  119152.10              2          1
# 4521          560   27       7  124995.98              1          1
# ...           ...  ...     ...        ...            ...        ...
# 6412          602   53       5   98268.84              1          0
# 8285          609   25      10       0.00              1          0
# 7853          730   47       7       0.00              1          1
# 1095          692   29       4       0.00              1          1
# 6929          628   39       1  115341.19              1          1
#
#       IsActiveMember  EstimatedSalary
# 6252               0         41788.37
# 4684               1        146379.30
# 1731               0         58561.31
# 4742               1        170679.74
# 4521               1        114669.79
# ...              ...              ...
# 6412               1         45038.29
# 8285               1        109895.16
# 7853               0         33373.26
# 1095               0         76755.99
# 6929               1        107674.30
#
# [2000 rows x 8 columns]

# %%
input_dataset.shape
# Out:
# (10000, 8)

# %%
# splitting into training and testing data

# %%
X_train, X_test, y_train, y_test = train_test_split(input_dataset, output_dataset, test_size=0.2, random_state=42)

# %%
X_test
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 6252    -0.564197 -0.660018 -0.695982  0.324119       0.807737  -1.547768
# 4684    -0.284834  0.388871 -1.387538 -1.225848       0.807737   0.646092
# 1731    -0.512463  0.484225 -0.350204 -1.225848       0.807737   0.646092
# 4742    -1.495407  1.914528  1.032908  0.683816       0.807737   0.646092
# 4521    -0.936681 -1.136786  0.687130  0.777477      -0.911583   0.646092
# ...           ...       ...       ...       ...            ...        ...
# 6412    -0.502117  1.342407 -0.004426  0.349118      -0.911583  -1.547768
# 8285    -0.429689 -1.327494  1.724464 -1.225848      -0.911583  -1.547768
# 7853     0.822271  0.770285  0.687130 -1.225848      -0.911583   0.646092
# 1095     0.429093 -0.946079 -0.350204 -1.225848      -0.911583   0.646092
# 6929    -0.233100  0.007457 -1.387538  0.622738      -0.911583   0.646092
#
#       IsActiveMember  EstimatedSalary
# 6252       -1.030670        -1.013811
# 4684        0.970243         0.804921
# 1731       -1.030670        -0.722147
# 4742        0.970243         1.227481
# 4521        0.970243         0.253524
# ...              ...              ...
# 6412        0.970243        -0.957298
# 8285        0.970243         0.170498
# 7853       -1.030670        -1.160142
# 1095       -1.030670        -0.405759
# 6929        0.970243         0.131879
#
# [2000 rows x 8 columns]

# %%
X_train.shape
# Out:
# (8000, 8)

# %%
# Creating Artificial Neural Network (ANN)

# %%
import tensorflow

# %%
from keras.layers import Dense, BatchNormalization
from keras.regularizers import L2
from keras.models import Sequential
from keras.callbacks import EarlyStopping

# %%
ann = Sequential()

# %%
ann.add(Dense(6, input_dim=8, activation='relu',kernel_regularizer=L2(l2=0.01)))   # implementation of L2 regularization
ann.add(BatchNormalization())   # implementation of Batch Normalization
ann.add(Dense(4, activation='relu', kernel_regularizer=L2(l2=0.01)))
ann.add(BatchNormalization())
ann.add(Dense(2, activation='relu', kernel_regularizer=L2(l2=0.01)))
ann.add(BatchNormalization())
ann.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\user\anaconda3\envs\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
ann.fit(X_train, y_train, batch_size=200, epochs=50, validation_data=(X_test, y_test), callbacks=EarlyStopping())  # implementation of Early Stopping
# Out:
# Epoch 1/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8383 - loss: 0.4580 - val_accuracy: 0.8280 - val_loss: 0.5686
# Epoch 2/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8362 - loss: 0.4557 - val_accuracy: 0.8315 - val_loss: 0.5365
# Epoch 3/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8391 - loss: 0.4459 - val_accuracy: 0.8335 - val_loss: 0.4733
# Epoch 4/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8475 - loss: 0.4327 - val_accuracy: 0.8380 - val_loss: 0.4700
# Epoch 5/50
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8472 - loss: 0.4311 - val_accuracy: 0.8315 - val_loss: 0.4715

# %%
ann.history

# %%
train_accuracy = ann.history.history['accuracy']
test_accuracy = ann.history.history['val_accuracy']

# %%
len(test_accuracy)
# Out:
# 5

# %%
# plotting the train_accuracy and test_accuracy
plt.plot([i for i in range(1, 6)], train_accuracy)
plt.plot([i for i in range(1, 6)], test_accuracy, c='red')
plt.show()

# %%
prd1 = ann.predict(X_train)
prd_data1 = []
for i in prd1:
    if i[0] > 0.5:
        prd_data1.append(1)
    else:
        prd_data1.append(0)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
prd = ann.predict(X_test)
prd_data = []
for i in prd:
    if i[0] > 0.5:
        prd_data.append(1)
    else:
        prd_data.append(0)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prd_data)*100
# Out:
# 83.15

# %%
accuracy_score(y_train, prd_data1)*100
# Out:
# 83.75

# %% [markdown]
# # For New Data

# %%
import numpy as np

# %%
input_data = np.array([[-0.564197, -0.660018, -0.695982, 0.324119, 0.807737, -1.547768, -1.030670, -1.013811]])

# Predict using the ANN model
prd = ann.predict(input_data)

# Process the prediction result
prd_data = []
for i in prd:
    if i[0] > 0.5:
        prd_data.append(1)
    else:
        prd_data.append(0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %%
y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    0
#        ..
# 6412    1
# 8285    0
# 7853    1
# 1095    1
# 6929    1
# Name: Exited, Length: 2000, dtype: int64
